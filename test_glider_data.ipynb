# %%
from scipy import signal
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import template_matching as tm

# %%
#Load data from matlab file
mat_data = loadmat('data_glider_ctd_casts.mat', squeeze_me = True)

glider_ctd_profiles = mat_data['glider_ctd_profiles']

# %%
# get varaibles from all vertical profiles. 
# variables are stored in tuples; each variable stores 131 arrays.

# z in m, values are negative
glider_ctd_profiles_z = glider_ctd_profiles['z'][()][:]

# glider_ctd_profiles_potential_temperature[1]

# temperature in C
glider_ctd_profiles_potential_temperature = glider_ctd_profiles['potential_temperature'][()][:]
glider_ctd_profiles_conservative_temperature = glider_ctd_profiles['conservative_temperature'][()][:]

# salinity
glider_ctd_profiles_practical_salinity = glider_ctd_profiles['practical_salinity'][()][:]
glider_ctd_profiles_absolute_salinity = glider_ctd_profiles['absolute_salinity'][()][:]

# density in kg/m^3
glider_ctd_profiles_density = glider_ctd_profiles['density'][()][:]
glider_ctd_profiles_density_anomaly = glider_ctd_profiles['density_anomaly'][()][:]

# %%
data_array = glider_ctd_profiles_density[40][:,]
coord = -glider_ctd_profiles_z[40][:,]

cut_sig, cut_coord = tm.find_correlation(data_array, coord, 3 , 1)
# Out:
# step
# loc_med =  443.0
# starting figure
# initialised fig
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-48436ffaef79> in <module>()
#       2 coord = -glider_ctd_profiles_z[40][:,]
#       3
# ----> 4 cut_sig, cut_coord = tm.find_correlation(data_array, coord, 3 , 1)
#
# /Users/Karina/Academic/OHW19/ohw19-projects-TMIVP/template_matching.py in find_correlation(in_signal, coord, template, cut_range)
#      53     ax3.plot(coord[:len(temp)]+coord[int(loc_med)]-coord[len(temp)]/2., temp, label='shifted template')
#      54     ax3.axvline(coord[cut_beg], ls='--', c='k')
# ---> 55     ax3.axvline(coord[cut_end], ls='--', c='k')
#      56     for ax in [ax0,ax1,ax2,ax3]:
#      57         ax.legend(bbox_to_anchor=(1,1))
#
# IndexError: index 447 is out of bounds for axis 0 with size 445

# %%
plt.plot(cut_coord, cut_sig)

# %%
# Out:
# array([   2.64517747,    2.85361401,    3.08190141,    3.32507684,
#           3.55832647,    3.80150133,    4.06452687,    4.33747755,
#           4.63027878,    4.94293048,    5.28039526,    5.63771031,
#           5.99006206,    6.34737586,    6.72453976,    7.11659098,
#           7.50367879,    7.87587792,    8.25800164,    8.64508729,
#           9.01728434,    9.38948071,    9.7765642 ,   10.17853475,
#          10.59042968,   10.99736122,   11.40429193,   11.8062593 ,
#          12.18341315,   12.55064122,   12.92283115,   13.30494544,
#          13.69698404,   14.09894688,   14.50587143,   14.90783269,
#          15.30979315,   15.7266402 ,   16.16333619,   16.62484344,
#          17.08138726,   17.50319314,   17.91011091,   18.32695265,
#          18.75868072,   19.21025736,   19.67175775,   20.10844535,
#          20.50543327,   20.86768407,   21.21008491,   21.55248517,
#          21.89984718,   22.24224629,   22.57968254,   22.91215594,
#          23.23966653,   23.56221432,   23.87979934,   24.19738387,
